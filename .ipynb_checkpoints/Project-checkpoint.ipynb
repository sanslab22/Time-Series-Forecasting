# %% [markdown]
# # CSCI 3360 Project

# %% [markdown]
# ## Instructions

# %%
#!pip install matplotlib numpy pandas 
import numpy
import math
import matplotlib.pyplot as plt
from collections import Counter
import pandas as pd
# run below code once to install ARIMA
#!pip install sktime
from sktime.forecasting.arima import AutoARIMA
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.performance_metrics.forecasting import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Academic Honesty Statement

# %%
first_name_one = "Fidel"
last_name_one  = "Arroyo"
first_name_two = "Sanjana"
last_name_two= "Arun"


print("****************************************************************")
print("CSCI 3360 Project")
print(f"completed by {first_name_one} {last_name_one} and  {first_name_two} {last_name_two}")
print(f"""
We, GROUP 11: {first_name_one} {last_name_one} and {first_name_two} {last_name_two}, certify that the following code
represents our own work. We have neither received nor given 
inappropriate assistance. We have not consulted with another
individual, other than a member of the teaching staff, regarding
the specifics of our project. We recognize that any 
unauthorized assistance or plagiarism will be handled in 
accordance with the University of Georgia's Academic Honesty
Policy and the policies of this course.
""")
print("****************************************************************")
# Out:
# ****************************************************************
# CSCI 3360 Project
# completed by Fidel Arroyo and  Sanjana Arun
#
# We, GROUP 11: Fidel Arroyo and Sanjana Arun, certify that the following code
# represents our own work. We have neither received nor given
# inappropriate assistance. We have not consulted with another
# individual, other than a member of the teaching staff, regarding
# the specifics of our project. We recognize that any
# unauthorized assistance or plagiarism will be handled in
# accordance with the University of Georgia's Academic Honesty
# Policy and the policies of this course.
#
# ****************************************************************

# %% [markdown]
# ## Loading

# %% [markdown]
# We will first load the data and have the orginal pd as wage_data.

# %%
wage_data = pd.read_csv('./median_average_wages.csv')

# %%
print(f"Shape: {wage_data.shape}")
print(f"Rows: {wage_data.shape[0]}")
print(f"Columns: {wage_data.shape[1]}")
# Out:
# Shape: (50, 31)
# Rows: 50
# Columns: 31

# %%
group_dfs = []
group_train = []
group_test = []
year_df = wage_data["year"]
split = math.floor(year_df.shape[0] * 0.20)
year_test = year_df[:split]
year_train = year_df[split:]
print(f"Split year is {year_df[split]}, so we are testing for any year after {year_df[split]}")

correlation_storage = []
median_storage = []
# Out:
# Split year is 2012, so we are testing for any year after 2012

# %% [markdown]
# ##  Exploratory Data Analysis

# %% [markdown]
# We will showcase our Exploratory Data analysis:  mean, minimum and maximum, and standard deviation for a training set (80%) split. We will also display the histograms for each categorical group.

# %%
i = 0;
for group in wage_data.columns:
    if (i > 0):
        temp_df = wage_data[group].dropna()
        test = temp_df[:split]
        train = temp_df[split:]
        trim = train.describe(include=numpy.number).loc[ ['mean', 'std', 'min', 'max', '50%'] ]
        print(f"Train {group}")
        print(trim)
        correlation = train.corr(year_train)
        print(f"Correlation between {group} and year: {correlation}")
        print()
        print()
        group_dfs.append(temp_df)
        group_train.append(train)
        group_test.append(test)
        correlation_storage.append([group, correlation])
        median_storage.append([group, train.median()])
    i+=1
# Out:
# Train median
# mean    19.857750
# std      0.875075
# min     18.780000
# max     21.450000
# 50%     19.385000
# Name: median, dtype: float64
# Correlation between median and year: 0.7829267929893973
#
#
# Train average
# mean    24.497000
# std      1.880201
# min     22.420000
# max     27.900000
# 50%     23.700000
# Name: average, dtype: float64
# Correlation between average and year: 0.9258716327106336
#
#
# Train men_median
# mean    23.083250
# std      0.797619
# min     21.510000
# max     24.270000
# 50%     23.260000
# Name: men_median, dtype: float64
# Correlation between men_median and year: -0.296969590750943
#
#
# Train men_average
# mean    27.880750
# std      1.599648
# min     26.200000
# max     31.150000
# 50%     26.990000
# Name: men_average, dtype: float64
# Correlation between men_average and year: 0.8324766914479996
#
#
# Train women_median
# mean    17.00050
# std      1.56914
# min     14.88000
# max     19.57000
# 50%     16.75000
# Name: women_median, dtype: float64
# Correlation between women_median and year: 0.9764693117738396
#
#
# Train women_average
# mean    20.540250
# std      2.598525
# min     17.010000
# max     24.680000
# 50%     20.230000
# Name: women_average, dtype: float64
# Correlation between women_average and year: 0.9845331319803365
#
#
# Train white_median
# mean    21.091250
# std      1.320882
# min     19.430000
# max     23.350000
# 50%     20.400000
# Name: white_median, dtype: float64
# Correlation between white_median and year: 0.8728525421320295
#
#
# Train white_average
# mean    25.73925
# std      2.38123
# min     23.08000
# max     29.86000
# 50%     24.73500
# Name: white_average, dtype: float64
# Correlation between white_average and year: 0.9421243905145325
#
#
# Train black_median
# mean    16.793000
# std      0.873476
# min     15.870000
# max     18.570000
# 50%     16.295000
# Name: black_median, dtype: float64
# Correlation between black_median and year: 0.7893697641611344
#
#
# Train black_average
# mean    20.276000
# std      1.432376
# min     18.360000
# max     22.710000
# 50%     19.625000
# Name: black_average, dtype: float64
# Correlation between black_average and year: 0.9212784678935164
#
#
# Train hispanic_median
# mean    15.665250
# std      0.606017
# min     14.270000
# max     16.520000
# 50%     15.715000
# Name: hispanic_median, dtype: float64
# Correlation between hispanic_median and year: -0.07982271577897085
#
#
# Train hispanic_average
# mean    19.243000
# std      0.896109
# min     18.010000
# max     21.330000
# 50%     18.995000
# Name: hispanic_average, dtype: float64
# Correlation between hispanic_average and year: 0.6734615190747538
#
#
# Train white_men_median
# mean    24.877750
# std      0.888532
# min     23.160000
# max     26.490000
# 50%     24.865000
# Name: white_men_median, dtype: float64
# Correlation between white_men_median and year: 0.44954852968776216
#
#
# Train white_men_average
# mean    29.65850
# std      2.23875
# min     27.34000
# max     33.96000
# 50%     28.41500
# Name: white_men_average, dtype: float64
# Correlation between white_men_average and year: 0.901815121879502
#
#
# Train black_men_median
# mean    18.435500
# std      0.788107
# min     16.900000
# max     19.740000
# 50%     18.670000
# Name: black_men_median, dtype: float64
# Correlation between black_men_median and year: -0.01800624750459173
#
#
# Train black_men_average
# mean    21.878250
# std      1.151667
# min     20.400000
# max     23.990000
# 50%     21.405000
# Name: black_men_average, dtype: float64
# Correlation between black_men_average and year: 0.7648878162510636
#
#
# Train hispanic_men_median
# mean    16.942250
# std      1.090466
# min     14.970000
# max     18.830000
# 50%     16.895000
# Name: hispanic_men_median, dtype: float64
# Correlation between hispanic_men_median and year: -0.5460971834082253
#
#
# Train hispanic_men_average
# mean    20.679250
# std      0.923364
# min     18.930000
# max     22.590000
# 50%     20.705000
# Name: hispanic_men_average, dtype: float64
# Correlation between hispanic_men_average and year: 0.2296387120662246
#
#
# Train white_women_median
# mean    17.652250
# std      1.934085
# min     15.220000
# max     20.560000
# 50%     17.360000
# Name: white_women_median, dtype: float64
# Correlation between white_women_median and year: 0.9767660575996558
#
#
# Train white_women_average
# mean    21.180500
# std      2.999085
# min     17.230000
# max     25.920000
# 50%     20.755000
# Name: white_women_average, dtype: float64
# Correlation between white_women_average and year: 0.9845572893146696
#
#
# Train black_women_median
# mean    15.477000
# std      1.298169
# min     13.380000
# max     17.650000
# 50%     15.195000
# Name: black_women_median, dtype: float64
# Correlation between black_women_median and year: 0.9477572179795274
#
#
# Train black_women_average
# mean    18.754000
# std      1.931436
# min     15.680000
# max     21.900000
# 50%     18.385000
# Name: black_women_average, dtype: float64
# Correlation between black_women_average and year: 0.9760672710599382
#
#
# Train hispanic_women_median
# mean    14.105500
# std      0.638801
# min     13.250000
# max     15.380000
# 50%     13.860000
# Name: hispanic_women_median, dtype: float64
# Correlation between hispanic_women_median and year: 0.8091759567897328
#
#
# Train hispanic_women_average
# mean    17.074000
# std      1.331617
# min     15.070000
# max     19.550000
# 50%     16.690000
# Name: hispanic_women_average, dtype: float64
# Correlation between hispanic_women_average and year: 0.9643546799337155
#
#
# Train recent_high-school_graduate
# mean    12.817083
# std      0.720244
# min     11.560000
# max     13.880000
# 50%     12.900000
# Name: recent_high-school_graduate, dtype: float64
# Correlation between recent_high-school_graduate and year: 0.4595061319716987
#
#
# Train men_recent_high-school_graduate
# mean    13.648750
# std      0.785285
# min     12.270000
# max     14.840000
# 50%     13.610000
# Name: men_recent_high-school_graduate, dtype: float64
# Correlation between men_recent_high-school_graduate and year: 0.42457997596501884
#
#
# Train women_recent_high-school_graduate
# mean    11.805417
# std      0.638469
# min     10.740000
# max     12.800000
# 50%     11.990000
# Name: women_recent_high-school_graduate, dtype: float64
# Correlation between women_recent_high-school_graduate and year: 0.4159876979311408
#
#
# Train recent_college_graduate
# mean    21.711667
# std      1.267204
# min     19.390000
# max     23.360000
# 50%     22.110000
# Name: recent_college_graduate, dtype: float64
# Correlation between recent_college_graduate and year: 0.5768806583179511
#
#
# Train men_recent_college_graduate
# mean    23.130417
# std      1.636703
# min     20.110000
# max     25.810000
# 50%     23.515000
# Name: men_recent_college_graduate, dtype: float64
# Correlation between men_recent_college_graduate and year: 0.62236928114976
#
#
# Train women_recent_college_graduate
# mean    20.689583
# std      1.137921
# min     18.630000
# max     22.390000
# 50%     20.620000
# Name: women_recent_college_graduate, dtype: float64
# Correlation between women_recent_college_graduate and year: 0.4701852860368271

# %%
i = 1
cols = wage_data.columns[i:]
for  df in group_train:
    plt.figure()
    df.hist()
    plt.suptitle(f" {cols[i - 1]} ")
    i += 1
    plt.show()
    plt.close()

# %%
i = 1
for df in group_train:
    a = wage_data.columns[i]
    b = wage_data.columns[0]
    plt.figure(figsize=(8,6))
    aligned = pd.concat([df, year_train], axis = 1, keys = [a, b]).dropna()
    plt.scatter(aligned[a], aligned[b], color='red', marker='+')
    plt.title(a + " vs. " + b)
    plt.grid(True)
    plt.xlabel(a)
    plt.ylabel(b)
    plt.show()
    plt.close()
    i+=1

# %%
correlation_storage = sorted(correlation_storage, key=lambda x: abs(x[1]))
print(f"Top five least likely to support linear models: {[x[0] for x in correlation_storage[:5]]} with a value of {[x[1] for x in correlation_storage[:5]]} ")
print(f"Top five most likely to support linear models: {[x[0] for x in correlation_storage[-5:]]} with a value of {[x[1] for x in correlation_storage[-5:]]}")

median_storage= sorted(median_storage, key=lambda x: abs(x[1]))
print()
print(f"Bottom Ten columns based on medians: {[x[0] for x in median_storage[:10]]} with a value of {[x[1] for x in median_storage[:10]]} ")
print(f"Top Ten columns based on medians: {[x[0] for x in median_storage[-10:]]} with a value of {[x[1] for x in median_storage[-10:]]}")
# Out:
# Top five least likely to support linear models: ['black_men_median', 'hispanic_median', 'hispanic_men_average', 'men_median', 'women_recent_high-school_graduate'] with a value of [-0.01800624750459173, -0.07982271577897085, 0.2296387120662246, -0.296969590750943, 0.4159876979311408]
# Top five most likely to support linear models: ['black_women_average', 'women_median', 'white_women_median', 'women_average', 'white_women_average'] with a value of [0.9760672710599382, 0.9764693117738396, 0.9767660575996558, 0.9845331319803365, 0.9845572893146696]
#
# Bottom Ten columns based on medians: ['women_recent_high-school_graduate', 'recent_high-school_graduate', 'men_recent_high-school_graduate', 'hispanic_women_median', 'black_women_median', 'hispanic_median', 'black_median', 'hispanic_women_average', 'women_median', 'hispanic_men_median'] with a value of [11.989999999999998, 12.899999999999999, 13.61, 13.86, 15.195, 15.715, 16.295, 16.689999999999998, 16.75, 16.895]
# Top Ten columns based on medians: ['white_women_average', 'black_men_average', 'recent_college_graduate', 'men_median', 'men_recent_college_graduate', 'average', 'white_average', 'white_men_median', 'men_average', 'white_men_average'] with a value of [20.755, 21.405, 22.11, 23.259999999999998, 23.515, 23.7, 24.735, 24.865000000000002, 26.990000000000002, 28.415]

# %% [markdown]
# ##  Models

# %% [markdown]
# We will begin implementing both the linear regression and ARIMA models.

# %%
arima_df = wage_data[:]
arima_df["year"] = pd.to_datetime(arima_df["year"], format="%Y")
arima_df = arima_df.sort_values("year")
arima_df = arima_df.set_index("year")
arima_df.index = arima_df.index.to_period('Y')
forcast_results = []
metrics = []

# %%
from statsmodels.tsa.api import VAR
df_filled = arima_df.interpolate(method="linear", limit_direction="both")
df_diff = df_filled.diff().dropna()
train = df_diff[:-split]
test = df_diff.tail(split)
model = VAR(train)
results = model.fit(maxlags=3)
lag_order = results.k_ar
forecast_input = train.values[-lag_order:]
forecast = results.forecast(y=forecast_input, steps=len(test))
forecast_df = pd.DataFrame(forecast, index=test.index, columns=df_diff.columns)
df_diff.index = df_diff.index.to_timestamp()
forecast_df.index = forecast_df.index.to_timestamp()

# %%
for col in df_diff.columns:
    plt.figure(figsize=(8,4))
    plt.plot(df_diff.index, df_diff[col], label="Original")
    plt.plot(forecast_df.index, forecast_df[col], label="Forecast", linestyle="--")
    plt.title(f"VAR Forecast for {col}")
    plt.legend()
    plt.show()
    plt.close()

# %% [markdown]
# ##  Evaluation Metrics

# %% [markdown]
# We will now give the RMSE of our models

# %%
overall_rmse = numpy.sqrt(mean_squared_error(test.values, forecast_df.values))
print(f"Overall RMSE for VAR: {overall_rmse:.4f}")
# Out:
# Overall RMSE for VAR: 0.9270

# %%
rmse_dict = {}

for col in test.columns:
    rmse = numpy.sqrt(mean_squared_error(test[col], forecast_df[col]))
    rmse_dict[col] = rmse

print("RMSE ARIMA VAR per column:")
for col, rmse in rmse_dict.items():
    print(f"{col}: {rmse:.4f}")
# Out:
# RMSE ARIMA VAR per column:
# median: 0.6430
# average: 0.8868
# men_median: 0.9304
# men_average: 1.0912
# women_median: 0.6922
# women_average: 0.7154
# white_median: 0.8941
# white_average: 0.8533
# black_median: 0.7096
# black_average: 0.9910
# hispanic_median: 0.7885
# hispanic_average: 0.7923
# white_men_median: 0.8426
# white_men_average: 1.0532
# black_men_median: 1.0237
# black_men_average: 1.3292
# hispanic_men_median: 1.0724
# hispanic_men_average: 0.9884
# white_women_median: 0.6074
# white_women_average: 0.6809
# black_women_median: 0.6254
# black_women_average: 0.8430
# hispanic_women_median: 0.6275
# hispanic_women_average: 0.6062
# recent_high-school_graduate: 0.5621
# men_recent_high-school_graduate: 0.6188
# women_recent_high-school_graduate: 0.7342
# recent_college_graduate: 1.2450
# men_recent_college_graduate: 1.6242
# women_recent_college_graduate: 1.5446

# %%
sorted_rmse = dict(sorted(rmse_dict.items(), key= lambda item: item[1]))
print()
print()
print(f"Bottom five based on RMSE: {[x[0] for x in list(sorted_rmse.items())[:5]]} with a value of {[x[1] for x in list(sorted_rmse.items())[:5]]} ")
print()
print(f"Top five based on RMSE: {[x[0] for x in list(sorted_rmse.items())[-5:]]} with a value of {[x[1] for x in list(sorted_rmse.items())[-5:]]}")
# Out:
# Bottom five based on RMSE: ['recent_high-school_graduate', 'hispanic_women_average', 'white_women_median', 'men_recent_high-school_graduate', 'black_women_median'] with a value of [0.5620945488319881, 0.60620382870658, 0.6073564302610543, 0.6187968223357497, 0.6254145397343917]
#
# Top five based on RMSE: ['men_average', 'recent_college_graduate', 'black_men_average', 'women_recent_college_graduate', 'men_recent_college_graduate'] with a value of [1.0912178925857519, 1.2450104442206886, 1.3292434710877263, 1.5446201526178125, 1.6241760736748645]
